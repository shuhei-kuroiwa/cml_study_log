# %%
import pandas

# %%
df = pandas.read_csv('/Users/kavuk/Desktop/GitHub/cml_study_log/implementations:/women.csv')

# %%
df.head()
# Out:
#    GP  village  reserved  female  irrigation  water
# 0   1        2         1       1           0     10
# 1   1        1         1       1           5      0
# 2   2        2         1       1           2      2
# 3   2        1         1       1           4     31
# 4   3        2         0       0           0      0
